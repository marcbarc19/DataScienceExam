# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('Data\climate_change_indicators.csv')

# Display the DataFrame
print(df)
# Out:
#      ObjectId                       Country ISO2 ISO3  \
# 0           1  Afghanistan, Islamic Rep. of   AF  AFG
# 1           2                       Albania   AL  ALB
# 2           3                       Algeria   DZ  DZA
# 3           4                American Samoa   AS  ASM
# 4           5      Andorra, Principality of   AD  AND
# ..        ...                           ...  ...  ...
# 220       221                Western Sahara   EH  ESH
# 221       222                         World  NaN  WLD
# 222       223                Yemen, Rep. of   YE  YEM
# 223       224                        Zambia   ZM  ZMB
# 224       225                      Zimbabwe   ZW  ZWE
#
#                                              Indicator            Unit  \
# 0    Temperature change with respect to a baseline ...  Degree Celsius
# 1    Temperature change with respect to a baseline ...  Degree Celsius
# 2    Temperature change with respect to a baseline ...  Degree Celsius
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Plot a regression plot using seaborn
sns.regplot(x='Year', y='Value', data=melted_df)

# Add title and labels
plt.title('Regression Plot')
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 6
#       2 import matplotlib.pyplot as plt
#       5 # Plot a regression plot using seaborn
# ----> 6 sns.regplot(x='Year', y='Value', data=melted_df)
#       8 # Add title and labels
#       9 plt.title('Regression Plot')
#
# File c:\Users\mlj\OneDrive - Aarhus Universitet\MA 2. Semester\Data Science\DataScienceExam\data_sci_env\Lib\site-packages\seaborn\regression.py:775, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     773 scatter_kws["marker"] = marker
#     774 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 775 plotter.plot(ax, scatter_kws, line_kws)
#     776 return ax
#
# ...

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('Data/ghg-emissions.csv')

# Melt the DataFrame to convert it from wide to long format
melted_df = pd.melt(df, id_vars=['iso', 'Country/Region', 'unit'], var_name='Year', value_name='Value')


#melted_df['Year'] = pd.to_datetime(melted_df['Year'], format='%Y')

melted_df['Value'] = melted_df['Value'].astype(str)

# Display the melted DataFrame
#print(melted_df)

#sns.lineplot(data=melted_df, x='Year', y='Value', hue='Country/Region', marker='o')

# %%
from plotnine import ggplot, aes, geom_line


( 
    ggplot(melted_df) 
    + aes(x = "Year", y = "Value", color = "Country/Region")
    + geom_line()
)
# Out:
# c:\Users\mlj\OneDrive - Aarhus Universitet\MA 2. Semester\Data Science\DataScienceExam\data_sci_env\Lib\site-packages\plotnine\geoms\geom_path.py:113: PlotnineWarning: geom_path: Each group consist of only one observation. Do you need to adjust the group aesthetic?
