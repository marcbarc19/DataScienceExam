# %%
import pandas as pd

# %%
gov = pd.read_csv("Data/resources/readiness/governance.csv")
print(gov)
# Out:
#     ISO3                              Name      1995      1996      1997  \
# 0    AFG                       Afghanistan  0.132619  0.132619  0.137714
# 1    ALB                           Albania  0.379200  0.379200  0.366713
# 2    DZA                           Algeria  0.288133  0.288133  0.277152
# 3    AND                           Andorra       NaN       NaN       NaN
# 4    AGO                            Angola  0.196202  0.196202  0.192119
# ..   ...                               ...       ...       ...       ...
# 187  VEN  Venezuela, Bolivarian Republic o  0.375318  0.375318  0.375252
# 188  VNM                          Viet Nam  0.443079  0.443079  0.440360
# 189  YEM                             Yemen  0.313508  0.313508  0.304431
# 190  ZMB                            Zambia  0.396951  0.396951  0.410970
# 191  ZWE                          Zimbabwe  0.388184  0.388184  0.374875
#
#          1998      1999      2000      2001      2002  ...      2012  \
# ...
